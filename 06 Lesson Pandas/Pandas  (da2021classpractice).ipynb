# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.1.3

# %%
# How  to create a dataframe 
students = {"Name": ["Braund, Mr. Owen Harris", "Allen, Mr. William Henry", "Bonnell, Miss. Elizabeth"], 
            "Marks": [22, 35, 58], 
            "Sex": ["male", "male", "female"]}

# %%
# python dic
students
# Out:
# {'Name': ['Braund, Mr. Owen Harris',
#   'Allen, Mr. William Henry',
#   'Bonnell, Miss. Elizabeth'],
#  'Marks': [22, 35, 58],
#  'Sex': ['male', 'male', 'female']}

# %%
# how to create a pandas dataframe 
df= pd.DataFrame(students)

# %%
# check  the dataframe 
df
# Out:
#                        Name  Marks     Sex
# 0   Braund, Mr. Owen Harris     22    male
# 1  Allen, Mr. William Henry     35    male
# 2  Bonnell, Miss. Elizabeth     58  female

# %%
# empty  dataframe 

dfempty=pd.DataFrame()
dfempty
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df
# Out:
#                        Name  Marks     Sex
# 0   Braund, Mr. Owen Harris     22    male
# 1  Allen, Mr. William Henry     35    male
# 2  Bonnell, Miss. Elizabeth     58  female

# %%
# select marks 
df['Marks']
# Out:
# 0    22
# 1    35
# 2    58
# Name: Marks, dtype: int64

# %%
# select sex 
df['Sex']
# Out:
# 0      male
# 1      male
# 2    female
# Name: Sex, dtype: object

# %%
# view the first 2 rows 
df.head()
# Out:
#                        Name  Marks     Sex
# 0   Braund, Mr. Owen Harris     22    male
# 1  Allen, Mr. William Henry     35    male
# 2  Bonnell, Miss. Elizabeth     58  female

# %%
# view the last 2  rows 
df.tail(1)
# Out:
#                        Name  Marks     Sex
# 2  Bonnell, Miss. Elizabeth     58  female

# %%
df.max()
# Out:
# Name     Braund, Mr. Owen Harris
# Marks                         58
# Sex                         male
# dtype: object

# %%
# df.describe()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Marks   3 non-null      int64
#  2   Sex     3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %% [markdown]
# # How do I read and write tabular data?

# %%
# read datas from  csv 
telcom_data=pd.read_csv('data/Telco_Churn.csv')

# %%
telcom_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
telcom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
telcom_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# read data from ex

medal_data=pd.read_excel('Medals.xlsx')

# %%
medal_data.head(6)
# Out:
#    Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0     1    United States of America    39      41      33    113
# 1     2  People's Republic of China    38      32      18     88
# 2     3                       Japan    27      14      17     58
# 3     4               Great Britain    22      21      22     65
# 4     5                         ROC    20      28      23     71
# 5     6                   Australia    17       7      22     46
#
#    Rank by Total
# 0              1
# 1              2
# 2              5
# 3              4
# 4              3
# 5              6

# %%
medal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           93 non-null     int64
#  1   Team/NOC       93 non-null     object
#  2   Gold           93 non-null     int64
#  3   Silver         93 non-null     int64
#  4   Bronze         93 non-null     int64
#  5   Total          93 non-null     int64
#  6   Rank by Total  93 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 5.2+ KB

# %%
medal_data.describe()
# Out:
#             Rank       Gold     Silver     Bronze       Total  Rank by Total
# count  93.000000  93.000000  93.000000  93.000000   93.000000      93.000000
# mean   46.333333   3.655914   3.634409   4.322581   11.612903      43.494624
# std    26.219116   7.022471   6.626339   6.210372   19.091332      24.171769
# min     1.000000   0.000000   0.000000   0.000000    1.000000       1.000000
# 25%    24.000000   0.000000   0.000000   1.000000    2.000000      23.000000
# 50%    46.000000   1.000000   1.000000   2.000000    4.000000      47.000000
# 75%    70.000000   3.000000   4.000000   5.000000   11.000000      66.000000
# max    86.000000  39.000000  41.000000  33.000000  113.000000      77.000000

# %% [markdown]
# # Read data from  html

# %%
kenya_counties=pd.read_html('https://en.wikipedia.org/wiki/Counties_of_Kenya')[2]

# %%
kenya_counties.head()
# Out:
#    Code            County FormerProvince  Area(km2)  Population(2009 Census)  \
# 0   1.0  Mombasa (County)          Coast      212.5                   939370
# 1   2.0             Kwale          Coast     8270.3                   649931
# 2   3.0            Kilifi          Coast    12245.9                  1109735
# 3   4.0        Tana River          Coast    35375.8                   240075
# 4   5.0              Lamu          Coast     6497.7                   191539
#
#    Population(2019 Census)         Capital
# 0                  1208333  Mombasa (City)
# 1                   866820           Kwale
# 2                  1453787          Kilifi
# 3                   315943            Hola
# 4                   143920            Lamu

# %%
kenya_counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Code                     47 non-null     float64
#  1   County                   47 non-null     object
#  2   FormerProvince           47 non-null     object
#  3   Area(km2)                48 non-null     float64
#  4   Population(2009 Census)  48 non-null     int64
#  5   Population(2019 Census)  48 non-null     int64
#  6   Capital                  48 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 2.8+ KB

# %%
mpesa= pd.read_json('data/testapi.json')

# %%
mpesa
# Out:
#                        Name  Marks     Sex
# 0   Braund, Mr. Owen Harris     22    male
# 1  Allen, Mr. William Henry     35    male
# 2  Bonnell, Miss. Elizabeth     58  female

# %%
# Or run this cell if you're in a notebook:
! pip install PyMySQL

# %%
# sqlite3 is used to create a connection to a database which we can then use to generate a DataFrame through a SELECT query.
import pymysql

# %%
# So first we'll make a connection to a SQLite database file:
conn = pymysql.connect(
    host='localhost',
    port=int(3306),
    user="root",
    passwd='1234',
    db="jumiaa_store",
    charset='utf8mb4')

# %%
# In Our  SQLite database we have a table called user_details

# By passing a SELECT query and our con, we can read from the user_details table:

df = pd.read_sql_query("SELECT * FROM customers",conn)
df.head()
# Out:
#    customer_id first_name  last_name  birth_date         phone    address  \
# 0            1        Joe     Mutale  1986-03-28  781-932-9754    0 Saace
# 1            2       Fred  Vilakati   1986-04-13  804-427-9456       Coml
# 2            3      Brian     Muyuda  1985-02-07  719-724-7869   Junction
# 3            4       John    Muchiri  1974-04-14  407-231-8017    Terrace
# 4            5    Clemmie      Banda  1973-11-07          None    5 Spohn
#
#       city state  points
# 0  Nairobi    MA    2273
# 1     Cape    VA     947
# 2   Dodoma    CO    2967
# 3  Mombasa    FL     457
# 4   Kisumu    Ks    3675

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  11 non-null     int64
#  1   first_name   11 non-null     object
#  2   last_name    11 non-null     object
#  3   birth_date   11 non-null     object
#  4   phone        9 non-null      object
#  5   address      11 non-null     object
#  6   city         11 non-null     object
#  7   state        11 non-null     object
#  8   points       11 non-null     int64
# dtypes: int64(2), object(7)
# memory usage: 920.0+ bytes

# %%
df.tail()
# Out:
#     customer_id first_name last_name  birth_date         phone    address  \
# 6             7      Ilene     Otile  1964-08-30  615-641-4759   Crossing
# 7             8      Chirs     Brown  1993-07-17  941-527-3977     Center
# 8             9     Mutula   Kilonzo  1992-05-23  559-181-3744      Trail
# 9            10      Uhuru    Corupt  1969-10-13  404-246-3370     Avenue
# 10           11     Wilson     Smith  1990-01-01          None    address
#
#       city state  points
# 6   Lusaka    TN    1672
# 7    Abuja    FL     205
# 8    Addis    CA    1486
# 9    Lagos    GA     796
# 10    city    CA       0

# %%
df.to_csv('jumiadata.csv')

# %%
#The equivalent read function to_excel() will reload the data to a DataFrame:
telcom= pd.read_excel('data/telcom.xlsx', sheet_name='customers')
telcom.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
telcom_excel['MonthlyCharges']
# Out:
# 0        29.85
# 1        56.95
# 2        53.85
# 3        42.30
# 4        70.70
#          ...
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7041     74.40
# 7042    105.65
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
#To select multiple columns, use a list of column names within the selection brackets [].
revenue = telcom_excel[ ["MonthlyCharges", "TotalCharges","Churn",'OnlineSecurity']  ]
revenue.head()
# Out:
#    MonthlyCharges TotalCharges Churn OnlineSecurity
# 0           29.85        29.85    No             No
# 1           56.95       1889.5    No            Yes
# 2           53.85       108.15   Yes            Yes
# 3           42.30      1840.75    No            Yes
# 4           70.70       151.65   Yes             No

# %% [markdown]
# # I’m interested in the customers who paid more than 100 in MonthlyCharges

# %%
paid_above100=telcom[ telcom['MonthlyCharges']>100 ]

# %%
paid_above100
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# ...          ...     ...            ...     ...        ...     ...
# 7022  7203-OYKCT    Male              0      No         No      72
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7034  0639-TSIQW  Female              0      No         No      67
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 8             Yes           Yes     Fiber optic             No  ...
# ...

# %%
paid_above100.count()
# Out:
# customerID          902
# gender              902
# SeniorCitizen       902
# Partner             902
# Dependents          902
# tenure              902
# PhoneService        902
# MultipleLines       902
# InternetService     902
# OnlineSecurity      902
# OnlineBackup        902
# DeviceProtection    902
# TechSupport         902
# StreamingTV         902
# StreamingMovies     902
# Contract            902
# PaperlessBilling    902
# PaymentMethod       902
# MonthlyCharges      902
# TotalCharges        902
# Churn               902
# dtype: int64

# %%
telcom['Contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
telcom.groupby("Contract").count()['customerID']
# Out:
# Contract
# Month-to-month    3875
# One year          1473
# Two year          1695
# Name: customerID, dtype: int64

# %%
telcom['Contract'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
telcom["ForecastSEPCO"] =telcom["MonthlyCharges"] * 10
telcom.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...
